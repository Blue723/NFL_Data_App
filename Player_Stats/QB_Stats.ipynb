# %%
#webscrape https://www.pro-football-reference.com/ for player data

# %%
import pandas as pd

# %%
#QB Passing

# %%
qb_passing_standard = pd.read_csv("QB_Passing_Standard.txt")
qb_passing_standard
# Out:
#       Rk             Player   Tm  Age Pos   G  GS   QBrec  Cmp  Att  ...  \
# 0      1  Patrick Mahomes*+  KAN   27  QB  17  17  14-3-0  435  648  ...
# 1      2     Justin Herbert  LAC   24  QB  17  17  10-7-0  477  699  ...
# 2      3          Tom Brady  TAM   45  QB  17  17   8-9-0  490  733  ...
# 3      4      Kirk Cousins*  MIN   34  QB  17  17  13-4-0  424  643  ...
# 4      5        Joe Burrow*  CIN   26  QB  16  16  12-4-0  414  606  ...
# ..   ...                ...  ...  ...  ..  ..  ..     ...  ...  ...  ...
# 101  102     Christian Kirk  JAX   26  WR  17  17     NaN    0    1  ...
# 102  103        Cooper Kupp  LAR   29  WR   9   9     NaN    0    1  ...
# 103  104       James Proche  BAL   26  WR  15   0     NaN    0    1  ...
# 104  105   Tommy Townsend*+  KAN   26   P  17   0     NaN    0    1  ...
# 105  106     Garrett Wilson  NYJ   22  WR  17  12     NaN    0    1  ...
#
#       Rate   QBR  Sk  Yds.1  Sk%  NY/A  ANY/A  4QC  GWD  Player-additional
# ...

# %%
qb_passing_air_yd_adv = pd.read_csv("QB_Passing_air_yd_Adv.txt")
qb_passing_air_yd_adv
# Out:
#       Rk             Player   Tm  Age Pos   G  GS  Cmp  Att   Yds   IAY  \
# 0      1  Patrick Mahomes*+  KAN   27  QB  17  17  435  648  5250  4686
# 1      2     Justin Herbert  LAC   24  QB  17  17  477  699  4739  4476
# 2      3          Tom Brady  TAM   45  QB  17  17  490  733  4694  4876
# 3      4      Kirk Cousins*  MIN   34  QB  17  17  424  643  4547  4800
# 4      5        Joe Burrow*  CIN   26  QB  16  16  414  606  4475  4121
# ..   ...                ...  ...  ...  ..  ..  ..  ...  ...   ...   ...
# 101  102     Christian Kirk  JAX   26  WR  17  17    0    1     0     1
# 102  103        Cooper Kupp  LAR   29  WR   9   9    0    1     0    25
# 103  104       James Proche  BAL   26  WR  15   0    0    1     0    33
# 104  105   Tommy Townsend*+  KAN   26   P  17   0    0    1     0     1
# 105  106     Garrett Wilson  NYJ   22  WR  17  12    0    1     0     9
#
#      IAY/PA   CAY  CAY/Cmp  CAY/PA   YAC  YAC/Cmp     -9999
# ...

# %%
qb_passing_standard.columns
# Out:
# Index(['Rk', 'Player', 'Tm', 'Age', 'Pos', 'G', 'GS', 'QBrec', 'Cmp', 'Att',
#        'Cmp%', 'Yds', 'TD', 'TD%', 'Int', 'Int%', '1D', 'Lng', 'Y/A', 'AY/A',
#        'Y/C', 'Y/G', 'Rate', 'QBR', 'Sk', 'Yds.1', 'Sk%', 'NY/A', 'ANY/A',
#        '4QC', 'GWD', 'Player-additional'],
#       dtype='object')

# %%
qb_passing_air_yd_adv.columns
# Out:
# Index(['Rk', 'Player', 'Tm', 'Age', 'Pos', 'G', 'GS', 'Cmp', 'Att', 'Yds',
#        'IAY', 'IAY/PA', 'CAY', 'CAY/Cmp', 'CAY/PA', 'YAC', 'YAC/Cmp', '-9999'],
#       dtype='object')

# %%
qb_passing_acc = pd.read_csv("QB_Passing_Accuracy_Adv.txt")
qb_passing_acc
# Out:
#       Rk             Player   Tm  Age Pos   G  GS  Cmp  Att   Yds  Bats  \
# 0      1  Patrick Mahomes*+  KAN   27  QB  17  17  435  648  5250     8
# 1      2     Justin Herbert  LAC   24  QB  17  17  477  699  4739    23
# 2      3          Tom Brady  TAM   45  QB  17  17  490  733  4694    11
# 3      4      Kirk Cousins*  MIN   34  QB  17  17  424  643  4547    14
# 4      5        Joe Burrow*  CIN   26  QB  16  16  414  606  4475    24
# ..   ...                ...  ...  ...  ..  ..  ..  ...  ...   ...   ...
# 101  102     Christian Kirk  JAX   26  WR  17  17    0    1     0     0
# 102  103        Cooper Kupp  LAR   29  WR   9   9    0    1     0     0
# 103  104       James Proche  BAL   26  WR  15   0    0    1     0     0
# 104  105   Tommy Townsend*+  KAN   26   P  17   0    0    1     0     0
# 105  106     Garrett Wilson  NYJ   22  WR  17  12    0    1     0     0
#
#      ThAwy  Spikes  Drops Drop%  BadTh    Bad%  OnTgt  OnTgt%     -9999
# ...

# %%
qb_passing_play_type = pd.read_csv("QB_Passing_Play_Type_Adv.txt")
qb_passing_play_type
# Out:
#       Rk             Player   Tm  Age Pos   G  GS  Cmp  Att   Yds  Plays  \
# 0      1  Patrick Mahomes*+  KAN   27  QB  17  17  435  648  5250     91
# 1      2     Justin Herbert  LAC   24  QB  17  17  477  699  4739     41
# 2      3          Tom Brady  TAM   45  QB  17  17  490  733  4694     23
# 3      4      Kirk Cousins*  MIN   34  QB  17  17  424  643  4547     20
# 4      5        Joe Burrow*  CIN   26  QB  16  16  414  606  4475     65
# ..   ...                ...  ...  ...  ..  ..  ..  ...  ...   ...    ...
# 101  102     Christian Kirk  JAX   26  WR  17  17    0    1     0      1
# 102  103        Cooper Kupp  LAR   29  WR   9   9    0    1     0      0
# 103  104       James Proche  BAL   26  WR  15   0    0    1     0      1
# 104  105   Tommy Townsend*+  KAN   26   P  17   0    0    1     0      0
# 105  106     Garrett Wilson  NYJ   22  WR  17  12    0    1     0      1
#
#      Yds.1  PassAtt  PassYds  RushAtt  RushYds  PassAtt.1  PassYds.1     -9999
# ...

# %%
qb_passing_pressure = pd.read_csv("QB_Passing_Pressure_Adv.txt")
qb_passing_pressure
# Out:
#       Rk             Player   Tm  Age Pos   G  GS  Cmp  Att   Yds  Sk  \
# 0      1  Patrick Mahomes*+  KAN   27  QB  17  17  435  648  5250  26
# 1      2     Justin Herbert  LAC   24  QB  17  17  477  699  4739  38
# 2      3          Tom Brady  TAM   45  QB  17  17  490  733  4694  22
# 3      4      Kirk Cousins*  MIN   34  QB  17  17  424  643  4547  46
# 4      5        Joe Burrow*  CIN   26  QB  16  16  414  606  4475  41
# ..   ...                ...  ...  ...  ..  ..  ..  ...  ...   ...  ..
# 101  102     Christian Kirk  JAX   26  WR  17  17    0    1     0   0
# 102  103        Cooper Kupp  LAR   29  WR   9   9    0    1     0   0
# 103  104       James Proche  BAL   26  WR  15   0    0    1     0   0
# 104  105   Tommy Townsend*+  KAN   26   P  17   0    0    1     0   0
# 105  106     Garrett Wilson  NYJ   22  WR  17  12    0    1     0   0
#
#      PktTime  Bltz  Hrry  Hits  Prss   Prss%  Scrm  Yds/Scr     -9999
# ...
