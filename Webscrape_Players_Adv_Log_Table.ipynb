# %%
'''
Webscrape table change into dataframe and save in files.
'''
# Out:
# '\nWebscrape table change into dataframe and save in files.\n'

# %%
import requests
import re

from bs4 import BeautifulSoup as bs

import time
import random

import pandas as pd

import numpy as np

import signal

import os

# %%
players_49ers_2018_url_li = [
 'http://www.pro-football-reference.com/players/A/ArmsAr01/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/B/BeatC.00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/B/BlaiRo00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/B/BoldVi00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/B/BourKe00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/B/BreiMa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/B/BuckDe00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/C/CeleGa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/C/ColbAd00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/C/CoylBr00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/D/DayxSh00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/D/DayeMa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/D/DelaRy00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/D/DunbSt00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/D/DwelRo00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/E/ExumAn00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/F/FostRe00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/G/GarcPi00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/G/GarnJo00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/G/GaroJi00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/G/GarvTe00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/G/GillGa01/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/G/GoodMa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/G/GouldRob01/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/H/HarrMa03/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/H/HolbCo00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/I/IgweGo00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/J/JameRi00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/J/JoneD.00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/J/JuszKy00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/K/KittGe00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/L/LeexEl00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/MabiGr00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/MagnEr00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/MarsCa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/McCaMa01/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/McGlMi00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/MitcEa99/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/MoorTa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/MorrAl00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/MoseEm00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/MostRa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/M/MullNi00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/N/NelsKy00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/N/NzeoMa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/O/OnwuJa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/P/PersMi00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/P/PettDa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/P/PiniBr00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/P/PoweTy01/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/R/ReedD.00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/R/RichWe00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/S/SherRi00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/S/SmitMa02/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/S/StalJo20/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/T/TartJa00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/T/TaumPi00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/T/TaylJu00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/T/TaylTr02/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/T/ThomSo00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/W/WardJi01/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/W/WarnFr00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/W/WatsDe99/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/W/WickCo00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/W/WillKW00/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/W/WilsJe01/gamelog/2018/advanced/',
 'http://www.pro-football-reference.com/players/W/WithAh00/gamelog/2018/advanced/']

# %%
def webscrape_player_name(url: str):
    #request html
    html = requests.get(url).text

    time.sleep(random.randrange(5,7))

    #parse html
    soup = bs(html, 'html.parser')

    #find header for player name
    h1 = soup.find_all('h1')[0]


    try:
        #get player name
        span = h1.find_all('span')[0]

        name = span.contents[0]

    except:
        name = False


    return name

# %%
year = 2018
team='49ers'

# %%
def webscrape_player_adv_log_table(url_li: list, team: str, year: int):
    '''
    url_li = teams roster url list in string
    '''
    
    for player_url in url_li:
        try:
            #scrape table
            df_tables = pd.read_html(player_url)

            if len(df_tables) > 1:
                #numer to label different tables fromw same player
                no = 0
                for table in df_tables:
                    
                    df = tables.droplevel(level=0, axis=1)

                    #get name
                    name = webscrape_player_name(player_url)

                    #to csv
                    #to local file
                    df.to_csv('NFL_Data_{}/{}/Players Log/{}_{}'.format(year, team, name,no))
                    
                    no+=1
                    
            else:
                df = df_tables[0].droplevel(level=0, axis=1)

                #get name
                name = webscrape_player_name(player_url)

                #to csv
                df.to_csv('NFL_Data_{}/{}/Players Log/{}'.format(year, team, name))

        except:
            pass
        
    return

# %%
webscrape_player_adv_log_table(url_li=players_49ers_2018_url_li[1:2], team=team, year=year)

# %%
df = pd.read_csv('player_adv_log_url_df')

# %%
# Loop through each column of the PLAYER_ADV_LOG_URL_DATAFRAME
for col in df.columns:
    
    #able to use year as last four digits of the column and convert to int
    webscrape_player_adv_log_table(url_li=df[col], year=int(col[:-4]))

# %%
a = 'a2018'
a[-4:]
# Out:
# '2018'

# %%
#see if working
df_tables = pd.read_html(players_49ers_2018_url_li[1])
df_tables
# Out:
# [  Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                    Rk               Date                 G#               Week
#  0                1.0         2018-09-23                3.0                3.0
#  1                2.0         2018-09-30                4.0                4.0
#  2                3.0         2018-10-07                5.0                5.0
#  3                4.0         2018-10-15                6.0                6.0
#  4                5.0         2018-10-21                7.0                7.0
#  5                6.0         2018-10-28                8.0                8.0
#  6                NaN            6 Games                NaN                NaN
#
#    Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#                   Age                 Tm Unnamed: 6_level_1                Opp
#  0             24.311                SFO                  @                KAN
# ...

# %%
webscrape_player_adv_log_table(url_li=players_49ers_2018_url_li, team='49ers', year=2018)

# %%
df = df_tables[0]
df
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk               Date                 G#               Week
# 0                1.0         2018-09-23                3.0                3.0
# 1                2.0         2018-09-30                4.0                4.0
# 2                3.0         2018-10-07                5.0                5.0
# 3                4.0         2018-10-15                6.0                6.0
# 4                5.0         2018-10-21                7.0                7.0
# 5                6.0         2018-10-28                8.0                8.0
# 6                NaN            6 Games                NaN                NaN
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#                  Age                 Tm Unnamed: 6_level_1                Opp
# 0             24.311                SFO                  @                KAN
# ...

# %%
def fix_columns(dataframe: None)
    
    '''
    dataframe = insert dataframe
    '''

    df_col_li = []

    for col in df.columns:

        c = list(col)

        join_col = '_'.join(c)

        df_col_li.append(join_col)


    df_col_li[:9] = [c[19:] for c in df_col_li[:9]]

# %%
df_col_li
# Out:
# ['Rk',
#  'Date',
#  'G#',
#  'Week',
#  'Age',
#  'Tm',
#  'Unnamed: 6_level_1',
#  'Opp',
#  'Result',
#  'Passing_Cmp',
#  'Passing_Att',
#  'Passing_Yds',
#  'Passing_1D',
#  'Passing_1D%',
#  'Passing_IAY',
#  'Passing_IAY/PA',
#  'Passing_CAY',
#  'Passing_CAY/Cmp',
#  'Passing_CAY/PA',
#  'Passing_YAC',
#  'Passing_YAC/Cmp',
#  'Passing_Drops',
#  'Passing_Drop%',
#  'Passing_BadTh',
#  'Passing_Bad%',
#  'Passing_Sk',
#  'Passing_Bltz',
#  'Passing_Hrry',
#  'Passing_Hits',
#  'Passing_Prss',
#  'Passing_Prss%',
#  'Passing_Scrm',
#  'Passing_Yds/Scr']
